# %% [markdown]
# <a href="https://colab.research.google.com/github/Inventrohyder/datartistry/blob/analysis/Output%20generation%20notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Connect to GitHub

# %%
# !mkdir /root/.ssh

# %%
# !mv /content/id_rsa /root/.ssh/
# !mv /content/id_rsa.pub /root/.ssh/
# !mv /content/known_hosts /root/.ssh/

# %%
# !chmod 700 /root/.ssh/id_rsa

# %%
# Clone the entire repo.
# !git clone -l -s git@github.com:Inventrohyder/datartistry.git
# %cd datartistry/
# !ls
# Out:
# Cloning into 'datartistry'...
# ...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 2663 (delta 7), reused 30 (delta 6), pack-reused 2625
# Receiving objects: 100% (2663/2663), 346.93 MiB | 19.86 MiB/s, done.
# Resolving deltas: 100% (468/468), done.
# Checking out files: 100% (4154/4154), done.
# /content/datartistry
#  data   Instructions.md   organize.py   ResumeParser  'testing notebook.ipynb'

# %% [markdown]
# ## Install requirements

# %%
# !pip install -r ResumeParser/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 24.2MB 2.0MB/s
# ...
#      |████████████████████████████████| 10.1MB 42.3MB/s
# ...
#      |████████████████████████████████| 5.6MB 37.9MB/s
# ...
#      |████████████████████████████████| 27.7MB 108kB/s
# ...
#      |████████████████████████████████| 276kB 44.9MB/s
# ...
#      |████████████████████████████████| 13.7MB 45.7MB/s
# ...
#      |████████████████████████████████| 2.1MB 41.4MB/s
# ...
#      |████████████████████████████████| 92kB 10.8MB/s
# ...
#      |████████████████████████████████| 3.2MB 36.6MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.1-cp36-cp36m-linux_x86_64.whl size=44074 sha256=75a45b8d1f7e0e646ee184fa0e48cc546d3d9844b71460556929242da72db3c8
#   Stored in directory: /root/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
# Successfully built PyYAML
# ERROR: xarray 0.15.1 has requirement pandas>=0.25, but you'll have pandas 0.24.2 which is incompatible.
# ...

# %% [markdown]
# **Ensure you restarted the runtime after the previous cell ran.**

# %%
# !python -m spacy download en
# Out:
# ...
#      |████████████████████████████████| 11.1MB 514kB/s
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.1.0-cp36-none-any.whl size=11074435 sha256=18d659f939fd16872d3194337b2bdacc9bd2aaa11b599a617b1acd034dd96eb3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ctwzelu5/wheels/39/ea/3b/507f7df78be8631a7a3d7090962194cf55bc1158572c0be77f
# Successfully built en-core-web-sm
# ...
#   Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %% [markdown]
# ## Generate the output txt files

# %%
# %cd /content/datartistry/ResumeParser/bin
# Out:
# /content/datartistry/ResumeParser/bin

# %%
# Run the main program to generate the output files
# !python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:pdfminer.pdfinterp:get_font: create: objid=22, spec={'Type': /'Font', 'Subtype': /'TrueType', 'Name': /'F5', 'BaseFont': /'Arial', 'Encoding': /'WinAnsiEncoding', 'FontDescriptor': <PDFObjRef:23>, 'FirstChar': 32, 'LastChar': 32, 'Widths': <PDFObjRef:467>}
# INFO:pdfminer.pdfpage:Page: {'Type': /'Page', 'Parent': <PDFObjRef:2>, 'Resources': {'Font': {'F2': <PDFObjRef:10>, 'F4': <PDFObjRef:17>, 'F5': <PDFObjRef:22>, 'F1': <PDFObjRef:5>, 'F3': <PDFObjRef:12>}, 'ExtGState': {'GS7': <PDFObjRef:7>, 'GS8': <PDFObjRef:8>}, 'ProcSet': [/'PDF', /'Text', /'ImageB', /'ImageC', /'ImageI']}, 'MediaBox': [0, 0, 595.2, 841.92], 'Contents': <PDFObjRef:25>, 'Group': {'Type': /'Group', 'S': /'Transparency', 'CS': /'DeviceRGB'}, 'Tabs': /'S', 'StructParents': 2}
# ...

# %%
# !git add /content/datartistry/.
# !git commit -am "feat: generate output txt files"
# !git push
# Out:
# [analysis 0fe6acb] feat: generate output txt files
#  932 files changed, 386104 insertions(+)
#  create mode 100644 ResumeParser/data/output/admin-Addleshaw_Treliza Li_Office Manager.txt
#  create mode 100644 ResumeParser/data/output/admin-Adecco_AKALILI BAZILAH_Admin.txt
#  create mode 100644 ResumeParser/data/output/admin-Allen Glledhill_Yusri_Admin.txt
#  create mode 100644 ResumeParser/data/output/admin-Career Centre_AMIRUL HAMZA ABDULLAH_BD Exec.txt
#  create mode 100644 ResumeParser/data/output/admin-Chartnexus_Ng Sue Yee_Intern.txt
#  create mode 100644 ResumeParser/data/output/admin-Evolve_Azren Natasha_Admin Exec.txt
#  create mode 100644 ResumeParser/data/output/admin-Fosun_Beatrice Ling_Admin Asst.txt
#  create mode 100644 ResumeParser/data/output/admin-Graduan_MUHAMMAD HAFIFI BADRULDIN_Data Entry.txt
#  create mode 100644 ResumeParser/data/output/admin-Guard Capital_Godiva Tse_Office Manager.txt
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 3), reused 6 (delta 3), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From github.com:Inventrohyder/datartistry
#    f882f39..83068d5  analysis   -> origin/analysis
# Updating f882f39..83068d5
# Fast-forward
#  .../admin-BOC_Thomas Wong_Admin Officer.docx       |  Bin 27716 -> 0 bytes
#  ... Investment_Cheung Hiu Wai_Admin Secretary.docx |  Bin 13519 -> 0 bytes
#  .../admin-Cyrus Global_Jeanie Poh_Office Mgr.docx  |  Bin 204084 -> 0 bytes
#  ...min-Hypermarket_Nqobile Mthobi_Branch Admin.doc |  Bin 572416 -> 0 bytes
#  .../admin-Kini Mirni_Wong Sui Leng_Admin.docx      |  Bin 18117 -> 0 bytes
#  ...admin-LJ Hooker_Vivian Shiu_Office Manager.docx |  Bin 34315 -> 0 bytes
#  .../admin-Maju Hom_NORAZIRAWANI_Admin.doc          |  Bin 70144 -> 0 bytes
# ...
